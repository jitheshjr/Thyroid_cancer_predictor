# %% [markdown]
# # **IMPORTING ESSENTIAL LIBRARIES**

# %%
# Core Libraries
import pandas as pd
import numpy as np

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Preprocessing, Modeling, Evaluation
from sklearn.preprocessing import LabelEncoder, StandardScaler, KBinsDiscretizer,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score,f1_score,roc_auc_score,precision_recall_curve,auc,roc_curve,log_loss,average_precision_score
from imblearn.over_sampling import SMOTE

# Statistical
from scipy.stats import chi2_contingency,skew

# Machine Learning Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Model saving/loading
import joblib
import os

# %% [markdown]
# # **LOADING DATASET**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Data
df = pd.read_csv('/content/drive/MyDrive/DataMining/thyroid_cancer_risk_data.csv')
df.shape
# Out:
# (212691, 17)

# %%
# Creating a sample using 30% of data
df_sample = df.sample(frac=0.30, random_state=42)
df_sample.shape
# Out:
# (63807, 17)

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS & VISUALIZATION**

# %%
# Display Dataset
df.head()
# Out:
#    Patient_ID  Age  Gender  Country  Ethnicity Family_History  \
# 0           1   66    Male   Russia  Caucasian             No
# 1           2   29    Male  Germany   Hispanic             No
# 2           3   86    Male  Nigeria  Caucasian             No
# 3           4   75  Female    India      Asian             No
# 4           5   35  Female  Germany    African            Yes
#
#   Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  TSH_Level  \
# 0                Yes                No      No      No       No       9.37
# 1                Yes                No      No      No       No       1.83
# 2                 No                No      No      No       No       6.26
# 3                 No                No      No      No       No       4.10
# 4                Yes                No      No      No       No       9.10
#
#    T3_Level  T4_Level  Nodule_Size Thyroid_Cancer_Risk Diagnosis
# 0      1.67      6.16         1.08                 Low    Benign
# 1      1.73     10.54         4.05                 Low    Benign
# 2      2.59     10.57         4.61                 Low    Benign
# 3      2.62     11.04         2.46              Medium    Benign
# 4      2.11     10.71         2.11                High    Benign

# %%
# Initial Inspection
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63807 entries, 82562 to 166584
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           63807 non-null  int64
#  1   Age                  63807 non-null  int64
#  2   Gender               63807 non-null  object
#  3   Country              63807 non-null  object
#  4   Ethnicity            63807 non-null  object
#  5   Family_History       63807 non-null  object
#  6   Radiation_Exposure   63807 non-null  object
#  7   Iodine_Deficiency    63807 non-null  object
#  8   Smoking              63807 non-null  object
#  9   Obesity              63807 non-null  object
#  10  Diabetes             63807 non-null  object
#  11  TSH_Level            63807 non-null  float64
#  12  T3_Level             63807 non-null  float64
#  13  T4_Level             63807 non-null  float64
#  14  Nodule_Size          63807 non-null  float64
#  15  Thyroid_Cancer_Risk  63807 non-null  object
#  16  Diagnosis            63807 non-null  object
# dtypes: float64(4), int64(2), object(11)
# memory usage: 8.8+ MB

# %%
# Summary Statistics
df_sample.describe()
# Out:
#           Patient_ID           Age     TSH_Level      T3_Level      T4_Level  \
# count   63807.000000  63807.000000  63807.000000  63807.000000  63807.000000
# mean   106626.574639     51.973827      5.041010      2.002192      8.242059
# std     61294.419017     21.634870      2.858202      0.866376      2.164785
# min         1.000000     15.000000      0.100000      0.500000      4.500000
# 25%     53473.000000     33.000000      2.570000      1.250000      6.360000
# 50%    106970.000000     52.000000      5.030000      2.010000      8.230000
# 75%    160023.500000     71.000000      7.510000      2.750000     10.130000
# max    212691.000000     89.000000     10.000000      3.500000     12.000000
#
#         Nodule_Size
# count  63807.000000
# mean       2.504073
# std        1.443599
# min        0.000000
# 25%        1.260000
# 50%        2.510000
# 75%        3.760000
# max        5.000000

# %% [markdown]
# **Dropping Irrelevant and Potentially Leaky features**

# %%
df_sample.drop(columns=['Patient_ID','Thyroid_Cancer_Risk'], inplace=True)

# %% [markdown]
# **Listing Unique Value Counts**

# %%
print(df_sample.nunique())
# Out:
# Age                    75
# Gender                  2
# Country                10
# Ethnicity               5
# Family_History          2
# Radiation_Exposure      2
# Iodine_Deficiency       2
# Smoking                 2
# Obesity                 2
# Diabetes                2
# TSH_Level             991
# T3_Level              301
# T4_Level              751
# Nodule_Size           501
# Diagnosis               2
# dtype: int64

# %% [markdown]
# **Check Missing Values**

# %%
print(df_sample.isnull().sum())
# Out:
# Age                   0
# Gender                0
# Country               0
# Ethnicity             0
# Family_History        0
# Radiation_Exposure    0
# Iodine_Deficiency     0
# Smoking               0
# Obesity               0
# Diabetes              0
# TSH_Level             0
# T3_Level              0
# T4_Level              0
# Nodule_Size           0
# Diagnosis             0
# dtype: int64

# %% [markdown]
# **Check Duplicate Rows and Columns**

# %%
duplicate_rows = df_sample.duplicated()
print(f"Duplicate rows: {duplicate_rows.sum()}")

duplicate_columns = df_sample.T.duplicated()
print(f"Duplicate columns: {duplicate_columns.sum()}")
# Out:
# Duplicate rows: 0
# Duplicate columns: 0

# %% [markdown]
# **Listing Categorical and Numerical Features**

# %%
categorical_features = df_sample.select_dtypes(include=['object']).columns
numerical_features = df_sample.select_dtypes(include=['int64', 'float64']).columns

print("Categorical Features:", categorical_features)
print()
print("Numerical Features:", numerical_features)
# Out:
# Categorical Features: Index(['Gender', 'Country', 'Ethnicity', 'Family_History',
#        'Radiation_Exposure', 'Iodine_Deficiency', 'Smoking', 'Obesity',
#        'Diabetes', 'Diagnosis'],
#       dtype='object')
#
# Numerical Features: Index(['Age', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size'], dtype='object')

# %% [markdown]
# **Target and Feature Setup**

# %%
target_col = 'Diagnosis'
features = [col for col in df_sample.columns if col != target_col]

print("Target Column:", target_col)
print("Features:", features)
# Out:
# Target Column: Diagnosis
# Features: ['Age', 'Gender', 'Country', 'Ethnicity', 'Family_History', 'Radiation_Exposure', 'Iodine_Deficiency', 'Smoking', 'Obesity', 'Diabetes', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size']

# %% [markdown]
# **Outlier Analysis**

# %%
# Univariate Analysis for Numerical Features

print("Outlier Analysis by IQR method")

# IQR method to detect outliers
for col in numerical_features:
    Q1 = df_sample[col].quantile(0.25)
    Q3 = df_sample[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df_sample[(df_sample[col] < lower) | (df_sample[col] > upper)]
    print(f"{col}: {len(outliers)} outliers")
# Out:
# Outlier Analysis by IQR method
# Age: 0 outliers
# TSH_Level: 0 outliers
# T3_Level: 0 outliers
# T4_Level: 0 outliers
# Nodule_Size: 0 outliers

# %%
# Box Plot Analysis

sns.set(style="whitegrid")
# Plot setup
plt.figure(figsize=(15, 8))
for i, col in enumerate(numerical_features, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(data=df_sample, x=col, color='skyblue')
    plt.title(f'{col} - Boxplot')
    plt.tight_layout()

plt.suptitle('Boxplots of Key Numeric Features', fontsize=16, y=1.05)
plt.show()

# %%
# Unique values in Categorical Features
categorical_cols = df_sample.select_dtypes(include=['object']).columns

for col in categorical_cols:
    print(f"{col} unique values:", df_sample[col].unique())
# Out:
# Gender unique values: ['Male' 'Female']
# Country unique values: ['Russia' 'India' 'Brazil' 'Nigeria' 'China' 'USA' 'Japan' 'South Korea'
#  'UK' 'Germany']
# Ethnicity unique values: ['Middle Eastern' 'Asian' 'Caucasian' 'Hispanic' 'African']
# Family_History unique values: ['No' 'Yes']
# Radiation_Exposure unique values: ['No' 'Yes']
# Iodine_Deficiency unique values: ['Yes' 'No']
# Smoking unique values: ['No' 'Yes']
# Obesity unique values: ['Yes' 'No']
# Diabetes unique values: ['No' 'Yes']
# Diagnosis unique values: ['Malignant' 'Benign']

# %%
# Univariate Analysis for Categorical Features
plt.figure(figsize=(14, 20))

for i, col in enumerate(categorical_cols, 1):
    plt.subplot(5, 2, i)
    sns.countplot(data=df_sample, x=col, hue=col, palette='viridis', legend=False)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
# Bivariate Analysis (Categorical vs. Target)

plt.figure(figsize=(14, 20))

for i, col in enumerate(categorical_cols, 1):
    plt.subplot(5, 2, i)
    sns.countplot(data=df_sample, x=col, hue='Diagnosis')
    plt.title(f'{col} vs Diagnosis')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Statistical Testing: Correlations**

# %%
# Correlation heatmap for numerical features
plt.figure(figsize=(12, 10))
sns.heatmap(df[numerical_features].corr(), annot=True, cmap='coolwarm', linewidths=0.4, annot_kws={"size":6})
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# **Statistical Testing: Chi-Square Test**

# %%
significant_features = []
non_significant_features = []

results = []

for col in categorical_cols:
    contingency = pd.crosstab(df_sample[col], df_sample['Diagnosis'])
    chi2, p, dof, expected = chi2_contingency(contingency)
    results.append({'Feature': col, 'Chi2 Stat': chi2, 'P-Value': p})

    if p < 0.05:
        significant_features.append(col)
    else:
        non_significant_features.append(col)

# Convert to DataFrame
chi_df = pd.DataFrame(results)

# Display
print("============ Chi-Square Test Results ============")
print(chi_df.to_string(index=False))

print("\n✅ Significant Categorical Features (p < 0.05):")
print(significant_features)

print("\n❌ Non-Significant Categorical Features (p >= 0.05):")
print(non_significant_features)
# Out:
# ============ Chi-Square Test Results ============
#            Feature    Chi2 Stat       P-Value
#             Gender     0.132916  7.154273e-01
#            Country   860.646455 1.858544e-179
#          Ethnicity  1554.551118  0.000000e+00
#     Family_History  1271.278385 1.971900e-278
# Radiation_Exposure   448.471505  1.551528e-99
#  Iodine_Deficiency   639.209126 4.965280e-141
#            Smoking     0.035974  8.495691e-01
#            Obesity     0.815620  3.664638e-01
#           Diabetes     0.362280  5.472427e-01
#          Diagnosis 63801.397136  0.000000e+00
#
# ✅ Significant Categorical Features (p < 0.05):
# ['Country', 'Ethnicity', 'Family_History', 'Radiation_Exposure', 'Iodine_Deficiency', 'Diagnosis']
#
# ❌ Non-Significant Categorical Features (p >= 0.05):
# ['Gender', 'Smoking', 'Obesity', 'Diabetes']

# %% [markdown]
# **Dropping Non-Significant Categorical Features**

# %%
df_sample.drop(columns=['Gender', 'Smoking', 'Obesity', 'Diabetes'], inplace=True)

# Updating Categorical Features
categorical_features = df_sample.select_dtypes(include=['object']).columns

# Updating features
features = [col for col in df_sample.columns if col != target_col]

# %% [markdown]
# **Count Plot for Diagnosis based on Family History**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df_sample, x='Diagnosis', hue='Family_History', palette='plasma')
plt.title('Diagnosis based on Family History')
plt.xlabel('Diagnosis (0: Benign, 1: Malignant)')
plt.ylabel('Count')
plt.legend(title='Family History (0: No, 1: Yes)')
plt.show()

# %% [markdown]
# **Count Plot for Diagnosis based on Radiation Exposure**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df_sample, x='Diagnosis', hue='Radiation_Exposure', palette='plasma')
plt.title('Diagnosis based on Family History')
plt.xlabel('Diagnosis (0: Benign, 1: Malignant)')
plt.ylabel('Count')
plt.legend(title='Radiation Exposure (0: No, 1: Yes)')
plt.show()

# %% [markdown]
# **Count Plot for Diagnosis based on Iodine Deficiency**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df_sample, x='Diagnosis', hue='Iodine_Deficiency', palette='plasma')
plt.title('Diagnosis based on Family History')
plt.xlabel('Diagnosis (0: Benign, 1: Malignant)')
plt.ylabel('Count')
plt.legend(title='Iodine Deficiency (0: No, 1: Yes)')
plt.show()

# %% [markdown]
# **Skewness Analysis**

# %%
# Create a copy to store transformed values
df_transformed = df_sample.copy()

transformations = []

for col in numerical_features:
    col_skew = skew(df_sample[col])

    if col_skew > 1:
        # Apply log1p (log(x+1)) to right-skewed
        df_transformed[col] = np.log1p(df_sample[col])
        transformations.append((col, col_skew, 'log1p'))

    elif col_skew < -1:
        # Apply square to left-skewed
        df_transformed[col] = np.square(df_sample[col])
        transformations.append((col, col_skew, 'square'))

    else:
        # No transformation needed
        transformations.append((col, col_skew, 'none'))


# Convert to DataFrame for display
transformation_df = pd.DataFrame(transformations, columns=['Feature', 'Original Skewness', 'Applied Transformation'])

print("=== Feature Transformations for Skewness Correction ===")
print(transformation_df.to_string(index=False))
# Out:
# === Feature Transformations for Skewness Correction ===
#     Feature  Original Skewness Applied Transformation
#         Age          -0.000175                   none
#   TSH_Level           0.005549                   none
#    T3_Level          -0.004806                   none
#    T4_Level           0.010184                   none
# Nodule_Size          -0.004839                   none

# %% [markdown]
# # **DATA PREPROCESSING**

# %% [markdown]
# **Feature Engineering**

# %%
# Binning/Descretization
df_sample['TSH_Binned'] = pd.qcut(df_sample['TSH_Level'], q=4, labels=["Low", "Medium", "High", "Very High"])
df_sample['T3_Binned'] = pd.qcut(df_sample['T3_Level'], q=4, labels=["Low", "Medium", "High", "Very High"])
df_sample['T4_Binned'] = pd.qcut(df_sample['T4_Level'], q=4, labels=["Low", "Medium", "High", "Very High"])
df_sample['Age_Binned'] = pd.qcut(df_sample['Age'], q=4, labels=["Young", "Middle-aged", "Elderly", "Very Elderly"])
df_sample['Nodule_Size_Binned'] = pd.qcut(df_sample['Nodule_Size'], q=4, labels=["Small", "Medium", "Large", "Very Large"])

# DataFrame after Feature Engineering
df_sample.head()
# Out:
#         Age  Country       Ethnicity Family_History Radiation_Exposure  \
# 82562    81   Russia  Middle Eastern             No                 No
# 101549   19    India           Asian            Yes                 No
# 97401    44   Brazil       Caucasian            Yes                 No
# 105415   56  Nigeria        Hispanic             No                 No
# 152387   86  Nigeria        Hispanic            Yes                 No
#
#        Iodine_Deficiency  TSH_Level  T3_Level  T4_Level  Nodule_Size  \
# 82562                Yes       0.81      0.72      4.57         0.72
# 101549                No       9.90      2.38      6.17         0.70
# 97401                 No       0.96      0.95      7.92         3.79
# 105415                No       5.49      0.74      8.39         4.75
# 152387                No       7.28      3.04     10.79         4.57
#
#         Diagnosis TSH_Binned  T3_Binned  T4_Binned    Age_Binned  \
# 82562   Malignant        Low        Low        Low  Very Elderly
# 101549     Benign  Very High       High        Low         Young
# 97401      Benign        Low        Low     Medium   Middle-aged
# 105415  Malignant       High        Low       High       Elderly
# 152387     Benign       High  Very High  Very High  Very Elderly
#
#        Nodule_Size_Binned
# 82562               Small
# 101549              Small
# 97401          Very Large
# 105415         Very Large
# 152387         Very Large

# %% [markdown]
# **Encoding Categorical Features**

# %%
# Encoding Categorical Features

df_encoded = df_sample.copy()

one_hot_cols = ['Country', 'Ethnicity','TSH_Binned', 'T3_Binned', 'T4_Binned', 'Age_Binned', 'Nodule_Size_Binned']
binary_cols = ['Family_History', 'Radiation_Exposure', 'Iodine_Deficiency']

df_encoded = pd.get_dummies(df_encoded, columns=one_hot_cols, drop_first=True)

# Binary columns: map Yes/No to 1/0
for col in binary_cols:
    df_encoded[col] = df_sample[col].map({'No': 0, 'Yes': 1})

# Encode Target
df_encoded['Diagnosis'] = df_sample['Diagnosis'].map({'Benign': 0, 'Malignant': 1})

df_encoded.head()
# Out:
#         Age  Family_History  Radiation_Exposure  Iodine_Deficiency  TSH_Level  \
# 82562    81               0                   0                  1       0.81
# 101549   19               1                   0                  0       9.90
# 97401    44               1                   0                  0       0.96
# 105415   56               0                   0                  0       5.49
# 152387   86               1                   0                  0       7.28
#
#         T3_Level  T4_Level  Nodule_Size  Diagnosis  Country_China  ...  \
# 82562       0.72      4.57         0.72          1          False  ...
# 101549      2.38      6.17         0.70          0          False  ...
# 97401       0.95      7.92         3.79          0          False  ...
# 105415      0.74      8.39         4.75          1          False  ...
# 152387      3.04     10.79         4.57          0          False  ...
#
#         T3_Binned_Very High  T4_Binned_Medium  T4_Binned_High  \
# 82562                 False             False           False
# 101549                False             False           False
# 97401                 False              True           False
# 105415                False             False            True
# 152387                 True             False           False
#
#         T4_Binned_Very High  Age_Binned_Middle-aged  Age_Binned_Elderly  \
# 82562                 False                   False               False
# 101549                False                   False               False
# 97401                 False                    True               False
# 105415                False                   False                True
# 152387                 True                   False               False
#
#         Age_Binned_Very Elderly  Nodule_Size_Binned_Medium  \
# 82562                      True                      False
# 101549                    False                      False
# 97401                     False                      False
# 105415                    False                      False
# 152387                     True                      False
#
#         Nodule_Size_Binned_Large  Nodule_Size_Binned_Very Large
# 82562                      False                          False
# 101549                     False                          False
# 97401                      False                           True
# 105415                     False                           True
# 152387                     False                           True
#
# [5 rows x 37 columns]

# %% [markdown]
# **Handle Class Imbalance to reduce medical biases**

# %%
X = df_encoded.drop(columns=['Diagnosis'])
y = df_encoded['Diagnosis']

smt = SMOTE(random_state=42)
X_resampled, y_resampled = smt.fit_resample(X, y)

# Use y_resampled for stratification
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, stratify=y_resampled, test_size=0.2, random_state=42
)

# standardize
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# **Shape**

# %%
print("Original shape:", X.shape, y.shape)
print("After SMOTE:", X_resampled.shape, y_resampled.shape)
# Out:
# Original shape: (63807, 36) (63807,)
# After SMOTE: (97936, 36) (97936,)

# %% [markdown]
# # **CORRELATION ANALYSIS**

# %% [markdown]
# **Correlation With Diagnosis**

# %%
cor_target = df_encoded.corr()['Diagnosis'].sort_values(ascending=False)
cor_target = cor_target.drop('Diagnosis') # Dropped Target

# Plot the correlation
plt.figure(figsize=(14, 8))
cor_target.plot(kind='bar', color='teal')

# Plot settings
plt.title('Correlation of All Features with Diagnosis')
plt.ylabel('Correlation Coefficient')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Heat Map of Correlation with Target

target_col = 'Diagnosis'

# Compute correlation matrix with the target
correlation_with_target = df_encoded.corr()[[target_col]].sort_values(by=target_col, ascending=False)

# Drop the target itself
correlation_with_target = correlation_with_target.drop(index=target_col)

# Plot heatmap
plt.figure(figsize=(8, 12))
sns.heatmap(correlation_with_target, annot=True, cmap='coolwarm', linewidths=0.5)

plt.title(f'Feature Correlation with Target: {target_col}')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **MACHINE LEARNING: TRAIN MODELS**

# %%
# Define models
models = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "Naive Bayes": GaussianNB(),
    "Random Forest": RandomForestClassifier(class_weight='balanced',n_estimators=100,max_depth=25,min_samples_leaf=2,random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    "LightGBM": LGBMClassifier(random_state=42),
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=5),
    "Neural Network (MLP)": MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
}

results = []
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    results.append((name, accuracy))
    print(f"\n{name} Results:")
    print(f"Accuracy: {accuracy:.4f}")
    print(classification_report(y_test, y_pred))
# Out:
# Logistic Regression Results:
# Accuracy: 0.7740
#               precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79      9794
#            1       0.81      0.72      0.76      9794
#
#     accuracy                           0.77     19588
#    macro avg       0.78      0.77      0.77     19588
# weighted avg       0.78      0.77      0.77     19588
#
#
# Naive Bayes Results:
# Accuracy: 0.6914
#               precision    recall  f1-score   support
#
#            0       0.69      0.70      0.70      9794
#            1       0.70      0.68      0.69      9794
#
#     accuracy                           0.69     19588
#    macro avg       0.69      0.69      0.69     19588
# weighted avg       0.69      0.69      0.69     19588
#
#
# Random Forest Results:
# Accuracy: 0.8582
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87      9794
#            1       0.92      0.78      0.85      9794
#
#     accuracy                           0.86     19588
#    macro avg       0.87      0.86      0.86     19588
# weighted avg       0.87      0.86      0.86     19588
#
#
# Gradient Boosting Results:
# Accuracy: 0.8113
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83      9794
#            1       0.89      0.71      0.79      9794
#
#     accuracy                           0.81     19588
#    macro avg       0.83      0.81      0.81     19588
# weighted avg       0.83      0.81      0.81     19588
#
#
# AdaBoost Results:
# Accuracy: 0.7071
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71      9794
#            1       0.71      0.71      0.71      9794
#
#     accuracy                           0.71     19588
#    macro avg       0.71      0.71      0.71     19588
# weighted avg       0.71      0.71      0.71     19588
#
#
# Decision Tree Results:
# Accuracy: 0.7658
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76      9794
#            1       0.75      0.79      0.77      9794
#
#     accuracy                           0.77     19588
#    macro avg       0.77      0.77      0.77     19588
# weighted avg       0.77      0.77      0.77     19588
#
#
# XGBoost Results:
# Accuracy: 0.8542
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.87      9794
#            1       0.93      0.77      0.84      9794
#
#     accuracy                           0.85     19588
#    macro avg       0.87      0.85      0.85     19588
# weighted avg       0.87      0.85      0.85     19588
#
# [LightGBM] [Info] Number of positive: 39174, number of negative: 39174
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038827 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1189
# [LightGBM] [Info] Number of data points in the train set: 78348, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#
# LightGBM Results:
# Accuracy: 0.8528
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86      9794
#            1       0.93      0.77      0.84      9794
#
#     accuracy                           0.85     19588
#    macro avg       0.86      0.85      0.85     19588
# weighted avg       0.86      0.85      0.85     19588
#
#
# K-Nearest Neighbors Results:
# Accuracy: 0.7685
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.78      9794
#            1       0.79      0.73      0.76      9794
#
#     accuracy                           0.77     19588
#    macro avg       0.77      0.77      0.77     19588
# weighted avg       0.77      0.77      0.77     19588
#
#
# Neural Network (MLP) Results:
# Accuracy: 0.8355
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85      9794
#            1       0.89      0.77      0.82      9794
#
#     accuracy                           0.84     19588
#    macro avg       0.84      0.84      0.83     19588
# weighted avg       0.84      0.84      0.83     19588

# %% [markdown]
# **Results**

# %%
res_df = pd.DataFrame(results, columns=["Model", "Accuracy"])

# Sort results by accuracy
res_df = res_df.sort_values(by=["Accuracy"], ascending=[False])

# Display the sorted results
res_df
# Out:
#                   Model  Accuracy
# 2         Random Forest  0.858230
# 6               XGBoost  0.854196
# 7              LightGBM  0.852767
# 9  Neural Network (MLP)  0.835460
# 3     Gradient Boosting  0.811313
# 0   Logistic Regression  0.774045
# 8   K-Nearest Neighbors  0.768481
# 5         Decision Tree  0.765826
# 4              AdaBoost  0.707066
# 1           Naive Bayes  0.691444

# %% [markdown]
# **Visualization of Model Results**

# %%
plt.figure(figsize=(12, 8))
ax = sns.barplot(data=res_df, x="Model", y="Accuracy", palette="ocean")
plt.title("Model Accuracy Comparison")
plt.xlabel("Model")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Accuracy")

# Add accuracy values on top of each bar
for i, v in enumerate(res_df['Accuracy']):
    ax.text(i, v, f'{v:.4f}', ha='center', va='bottom')

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.show()

# %% [markdown]
# # **BEST MODEL**

# %%
rf_model = RandomForestClassifier(
    class_weight='balanced',
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)

# Predictions
y_pred_rf = rf_model.predict(X_test)
y_probs_rf = rf_model.predict_proba(X_test)[:, 1]

# Evaluation metrics
precision_vals, recall_vals, _ = precision_recall_curve(y_test, y_probs_rf)

print(f"Accuracy: {accuracy_score(y_test, y_pred_rf):.4f}")
print(f"Recall: {recall_score(y_test, y_pred_rf):.4f}") # Important-missing a true positive
print(f"Precision: {precision_score(y_test, y_pred_rf):.4f}") # False positive
print(f"F1 Score: {f1_score(y_test, y_pred_rf):.4f}")
print(f"ROC AUC: {roc_auc_score(y_test, y_probs_rf):.4f}")
print(f"PR AUC: {auc(recall_vals, precision_vals):.4f}")
print(f"Log Loss: {log_loss(y_test, y_probs_rf):.4f}")
# Out:
# Accuracy: 0.8713
# Recall: 0.8108
# Precision: 0.9225
# F1 Score: 0.8631
# ROC AUC: 0.9230
# PR AUC: 0.9398
# Log Loss: 0.3625

# %% [markdown]
# **Confusion Matrix**

# %%
# Confusion Matrix
cn = confusion_matrix(y_test, y_pred_rf)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cn, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant'], yticklabels=['Benign', 'Malignant'])
# Out:
# <Axes: >

# %% [markdown]
# **Feature Importance**

# %%
# Get feature importances and feature names
importances = rf_model.feature_importances_

# Get the feature names from the original DataFrame X before scaling
feature_names = X.columns

# Create a DataFrame for sorting
feat_imp_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Plot
plt.figure(figsize=(10, 8))
sns.barplot(data=feat_imp_df.head(20), x='Importance', y='Feature', palette='viridis')
plt.title('Top 20 Important Features - Random Forest')
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **MODEL SAVING**

# %% [markdown]
# **Save the Random Forest model**

# %%
# Save the Random Forest model
joblib.dump(rf_model, 'diagnosis_predictor.pkl',compress=3)
print("Random Forest model saved as 'diagnosis_predictor.pkl'")
# Out:
# Random Forest model saved as 'diagnosis_predictor.pkl'

# %%
binning_edges = {
    'TSH_Level': pd.qcut(df_sample['TSH_Level'], q=4, retbins=True, duplicates='drop')[1],
    'T3_Level': pd.qcut(df_sample['T3_Level'], q=4, retbins=True, duplicates='drop')[1],
    'T4_Level': pd.qcut(df_sample['T4_Level'], q=4, retbins=True, duplicates='drop')[1],
    'Age': pd.qcut(df_sample['Age'], q=4, retbins=True, duplicates='drop')[1],
    'Nodule_Size': pd.qcut(df_sample['Nodule_Size'], q=4, retbins=True, duplicates='drop')[1]
}

joblib.dump(binning_edges, 'binning_edges_diagnosis.pkl')
# Out:
# ['binning_edges_diagnosis.pkl']

# %%
joblib.dump(X.columns.tolist(), 'feature_columns_diagnosis.pkl')
# Out:
# ['feature_columns_diagnosis.pkl']

# %%
joblib.dump(scaler, 'scaler_diagnosis.pkl')
# Out:
# ['scaler_diagnosis.pkl']
